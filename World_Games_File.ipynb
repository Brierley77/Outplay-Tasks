# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import matplotlib
matplotlib.rcParams['axes.grid'] = True # show gridlines by default
# %matplotlib inline

from pandas import *

# %%
# Setting LOCATION as a file to be read.

# %%
LOCATION = 'UK_Games.csv'

# %%
# Setting UK_Games as the file, and asking for the columns 'Commodity Code' and 'Reporter Code' to be read as strings.
# I ask for my data UK_Games to show me the first 5 rows of my newly created data set.

# %%
UK_Games = read_csv(LOCATION, dtype={'Commodity Code':str, 'Reporter Code':str, 'Year': str})
UK_Games.head()
# Out:
#   Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             H3  2008    2008          2008                6             1
# 1             H3  2008    2008          2008                6             1
# 2             H3  2008    2008          2008                6             1
# 3             H3  2008    2008          2008                6             1
# 4             H3  2008    2008          2008                6             1
#
#    Trade Flow Code Trade Flow Reporter Code   Reporter  ...    Qty  \
# 0                1     Import            20    Andorra  ...      9
# 1                1     Import            36  Australia  ...  41869
# 2                2     Export            36  Australia  ...  11273
# 3                1     Import            40    Austria  ...   8200
# 4                2     Export            40    Austria  ...  31700
#
#    Alt Qty Unit Code Alt Qty Unit Alt Qty  Netweight (kg)  Gross weight (kg)  \
# ...

# %%
# Set new columns for my data set, so I can ignore columns I do not need.

# %%
COLUMNS = ['Year', 'Trade Flow', 'Reporter', 'Partner', 'Commodity', 'Commodity Code', 'Trade Value (US$)']
UK_Games = UK_Games[COLUMNS]

# %%
# Check to see if this has worked.

# %%
UK_Games.head()
# Out:
#    Year Trade Flow   Reporter         Partner  \
# 0  2008     Import    Andorra  United Kingdom
# 1  2008     Import  Australia  United Kingdom
# 2  2008     Export  Australia  United Kingdom
# 3  2008     Import    Austria  United Kingdom
# 4  2008     Export    Austria  United Kingdom
#
#                                            Commodity Commodity Code  \
# 0  Video games of a kind used with a television r...         950410
# 1  Video games of a kind used with a television r...         950410
# 2  Video games of a kind used with a television r...         950410
# 3  Video games of a kind used with a television r...         950410
# 4  Video games of a kind used with a television r...         950410
#
#    Trade Value (US$)
# 0                437
# 1            2779871
# 2             518147
# 3            1697509
# 4            1692801

# %%
# Seperated and created new data sets just focusing on imports and exports.

# %%
Games_imports = UK_Games[UK_Games['Trade Flow'] == 'Import']
Games_exports = UK_Games[UK_Games['Trade Flow'] == 'Export']

# %%
Games_imports.head()
# Out:
#    Year Trade Flow                          Reporter         Partner  \
# 0  2008     Import                           Andorra  United Kingdom
# 1  2008     Import                         Australia  United Kingdom
# 3  2008     Import                           Austria  United Kingdom
# 5  2008     Import                           Belgium  United Kingdom
# 7  2008     Import  Bolivia (Plurinational State of)  United Kingdom
#
#                                            Commodity Commodity Code  \
# 0  Video games of a kind used with a television r...         950410
# 1  Video games of a kind used with a television r...         950410
# 3  Video games of a kind used with a television r...         950410
# 5  Video games of a kind used with a television r...         950410
# 7  Video games of a kind used with a television r...         950410
#
#    Trade Value (US$)
# 0                437
# 1            2779871
# 3            1697509
# 5            2259465
# 7                484

# %%
Games_exports.head()
# Out:
#     Year Trade Flow   Reporter         Partner  \
# 2   2008     Export  Australia  United Kingdom
# 4   2008     Export    Austria  United Kingdom
# 6   2008     Export    Belgium  United Kingdom
# 10  2008     Export   Bulgaria  United Kingdom
# 12  2008     Export     Canada  United Kingdom
#
#                                             Commodity Commodity Code  \
# 2   Video games of a kind used with a television r...         950410
# 4   Video games of a kind used with a television r...         950410
# 6   Video games of a kind used with a television r...         950410
# 10  Video games of a kind used with a television r...         950410
# 12  Video games of a kind used with a television r...         950410
#
#     Trade Value (US$)
# 2              518147
# 4             1692801
# 6              429996
# 10              80847
# 12             656772

# %%
# Seperated import data for the year 2008

# %%
UKImportsIn2008 = Games_imports[Games_imports['Year'] == '2008']

# %%
UKImportsIn2008.head()
# Out:
#    Year Trade Flow                          Reporter         Partner  \
# 0  2008     Import                           Andorra  United Kingdom
# 1  2008     Import                         Australia  United Kingdom
# 3  2008     Import                           Austria  United Kingdom
# 5  2008     Import                           Belgium  United Kingdom
# 7  2008     Import  Bolivia (Plurinational State of)  United Kingdom
#
#                                            Commodity Commodity Code  \
# 0  Video games of a kind used with a television r...         950410
# 1  Video games of a kind used with a television r...         950410
# 3  Video games of a kind used with a television r...         950410
# 5  Video games of a kind used with a television r...         950410
# 7  Video games of a kind used with a television r...         950410
#
#    Trade Value (US$)
# 0                437
# 1            2779871
# 3            1697509
# 5            2259465
# 7                484

# %%
# Seeing who we imported the most from in terms of video game technology in 2008. 
# Table shows the top 10 importing countries to the UK in descending order in US $.

# %%
UKImportsIn2008.sort_values('Trade Value (US$)', ascending=False).head(10)
# Out:
#      Year Trade Flow     Reporter         Partner  \
# 92   2008     Import        Spain  United Kingdom
# 45   2008     Import      Ireland  United Kingdom
# 69   2008     Import  Netherlands  United Kingdom
# 49   2008     Import        Italy  United Kingdom
# 95   2008     Import       Sweden  United Kingdom
# 22   2008     Import      Denmark  United Kingdom
# 32   2008     Import       France  United Kingdom
# 20   2008     Import      Czechia  United Kingdom
# 36   2008     Import       Greece  United Kingdom
# 111  2008     Import          USA  United Kingdom
#
#                                              Commodity Commodity Code  \
# 92   Video games of a kind used with a television r...         950410
# 45   Video games of a kind used with a television r...         950410
# 69   Video games of a kind used with a television r...         950410
# 49   Video games of a kind used with a television r...         950410
# ...

# %%
# Seeing who exported the most in terms of video game technology in 2002.
# Table shows the top 10 exporting countries from the UK in descending order in US $.

# %%
UKExportsIn2002 = Games_exports[Games_exports['Year'] == '2002']
UKExportsIn2002.sort_values('Trade Value (US$)', ascending = False).head(10)
# Out:
#      Year Trade Flow     Reporter         Partner  \
# 291  2002     Export      Germany  United Kingdom
# 349  2002     Export          USA  United Kingdom
# 289  2002     Export       France  United Kingdom
# 300  2002     Export      Ireland  United Kingdom
# 293  2002     Export       Greece  United Kingdom
# 341  2002     Export       Sweden  United Kingdom
# 276  2002     Export        China  United Kingdom
# 283  2002     Export      Denmark  United Kingdom
# 270  2002     Export      Belgium  United Kingdom
# 322  2002     Export  Netherlands  United Kingdom
#
#                                              Commodity Commodity Code  \
# 291  Video games of a kind used with a television r...         950410
# 349  Video games of a kind used with a television r...         950410
# 289  Video games of a kind used with a television r...         950410
# 300  Video games of a kind used with a television r...         950410
# ...

# %%
# Grouping data sets.

# %%
groups = UK_Games.groupby('Trade Flow')

# %%
groups.get_group('Import').head()
# Out:
#    Year Trade Flow                          Reporter         Partner  \
# 0  2008     Import                           Andorra  United Kingdom
# 1  2008     Import                         Australia  United Kingdom
# 3  2008     Import                           Austria  United Kingdom
# 5  2008     Import                           Belgium  United Kingdom
# 7  2008     Import  Bolivia (Plurinational State of)  United Kingdom
#
#                                            Commodity Commodity Code  \
# 0  Video games of a kind used with a television r...         950410
# 1  Video games of a kind used with a television r...         950410
# 3  Video games of a kind used with a television r...         950410
# 5  Video games of a kind used with a television r...         950410
# 7  Video games of a kind used with a television r...         950410
#
#    Trade Value (US$)
# 0                437
# 1            2779871
# 3            1697509
# 5            2259465
# 7                484

# %%
# Grouped by a specific Country.

# %%
groups = UK_Games.groupby('Reporter')
groups.get_group('France').head()
# Out:
#      Year Trade Flow Reporter         Partner  \
# 32   2008     Import   France  United Kingdom
# 33   2008     Export   France  United Kingdom
# 153  2011     Import   France  United Kingdom
# 154  2011     Export   France  United Kingdom
# 288  2002     Import   France  United Kingdom
#
#                                              Commodity Commodity Code  \
# 32   Video games of a kind used with a television r...         950410
# 33   Video games of a kind used with a television r...         950410
# 153  Video games of a kind used with a television r...         950410
# 154  Video games of a kind used with a television r...         950410
# 288  Video games of a kind used with a television r...         950410
#
#      Trade Value (US$)
# 32            38410940
# 33            12258216
# 153           19364574
# 154            9769744
# 288           19630114

# %%
# Specified for columns reporter and trade flow to group and set this = to groups

# Then informed groups to only output france and import.

# %%
GROUPING_REPORTERFLOW = ['Reporter', 'Trade Flow']
groups = UK_Games.groupby (GROUPING_REPORTERFLOW)

GROUP_REPORTERFLOW = ('France', 'Import')
groups.get_group(GROUP_REPORTERFLOW)
# Out:
#      Year Trade Flow Reporter         Partner  \
# 32   2008     Import   France  United Kingdom
# 153  2011     Import   France  United Kingdom
# 288  2002     Import   France  United Kingdom
# 383  2005     Import   France  United Kingdom
#
#                                              Commodity Commodity Code  \
# 32   Video games of a kind used with a television r...         950410
# 153  Video games of a kind used with a television r...         950410
# 288  Video games of a kind used with a television r...         950410
# 383  Video games of a kind used with a television r...         950410
#
#      Trade Value (US$)
# 32            38410940
# 153           19364574
# 288           19630114
# 383           25678061

# %%
# Grouped by counrty to find out their import totals. 
# Only grabbed first 10.

# %%
Games_imports.groupby('Reporter')['Trade Value (US$)'].aggregate(sum).head(10)
# Out:
# Reporter
# Albania                    912
# Algeria                  20663
# Andorra                  32566
# Angola                   15213
# Antigua and Barbuda       2526
# Argentina                  402
# Aruba                      556
# Australia              9730504
# Austria                6720219
# Azerbaijan                1424
# Name: Trade Value (US$), dtype: int64

# %%
# Grouped by counrty to find out their export totals. 
# Only grabbed first 10.

# %%
Games_exports.groupby('Reporter')['Trade Value (US$)'].aggregate(sum).head(10)
# Out:
# Reporter
# Antigua and Barbuda        878
# Australia              1866840
# Austria                8136395
# Azerbaijan                 305
# Bahrain                   2694
# Belgium                3888385
# Brazil                     332
# Brunei Darussalam          158
# Bulgaria               2125381
# Canada                 1257786
# Name: Trade Value (US$), dtype: int64

# %%
# Finding top 5 importing counrties and their total value over the year 2014 - 2002.

# %%
Games_imports_totals = Games_imports.groupby('Reporter')[['Trade Value (US$)']].aggregate(sum)
Games_imports_totals.sort_values('Trade Value (US$)', ascending = False).head()
# Out:
#              Trade Value (US$)
# Reporter
# Spain                945525794
# Netherlands          326832745
# Ireland              297003863
# Italy                145716221
# Sweden               131772414

# %%
# Finding top 5 exporting counrties and their total value over the year 2014 - 2002.

# %%
Games_exports_totals = Games_exports.groupby('Reporter')[['Trade Value (US$)']].aggregate(sum)
Games_exports_totals.sort_values('Trade Value (US$)', ascending = False).head()
# Out:
#                       Trade Value (US$)
# Reporter
# Germany                      1633364442
# China                         997870577
# China, Hong Kong SAR          302538812
# Ireland                       125049563
# Netherlands                    69857331

# %%
# Plotting a graph showing the top 5 imports of video game technology and approx how much in the  100 millions

# %%
Top_5_Imports = Games_imports.groupby('Reporter')[['Trade Value (US$)']].aggregate(sum)
Top_5_Imports.sort_values('Trade Value (US$)', ascending =False).head().plot(kind='barh')

# %%
# PLotting a graph showing the top 5 expors of video game technology and apporx how much in the billions

# %%
Top_5_Exports = Games_exports.groupby('Reporter')[['Trade Value (US$)']].aggregate(sum)
Top_5_Exports.sort_values('Trade Value (US$)', ascending = False).head().plot(kind='barh')
